# %%
# !pip install openai
import requests
from bs4 import BeautifulSoup, NavigableString, Tag
import base64
import openai
from google.colab import userdata
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.51.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)

# %%
# First, let's grab the links to all the pages on the wiki
allPages = 'https://wiki.umiacs.umd.edu/umiacs/index.php/Special:AllPages'
response = requests.get(allPages)
soup = BeautifulSoup(response.content, 'html.parser')

pageset = set()

# Create a set of unique pages on the wiki
for link in soup.find_all('a'):
    href = link.get('href')

    # Remove all links which redirect to links that we've already gone to
    if href and href.startswith('/umiacs/index.php'):
        response = requests.get('https://wiki.umiacs.umd.edu' + href, allow_redirects=True)
        response_url = response.url
        pageset.add(response_url)
# Out:
# Success
# 344

# %%
# This function uses GPT to describe the image in the context of the current page

def describeImage(context, encodedImage):
    backgroundInfo = '''
    I am training a large language model (LLM) using information from a wiki,
    including both text and images.
    My goal is to convert all images from the wiki into detailed textual
    descriptions that the LLM can use for training.
    Your task is to describe each image in comprehensive detail, capturing
    all essential visual elements such as objects,
    people, actions, text, colors, and spatial relationships, as well as any
    implicit meaning the image conveys.
    The description should be thorough enough that the model could learn all
    relevant information from the image
    without actually seeing it.

    Please avoid vague descriptions and focus on specific details,
    ensuring the description accurately reflects the visual content. Also avoid
    any hallucinations.
    After I provide the wiki text and multiple image, provide the image description in full.
    Describe each image fully in a maximum of 200 words.
    '''

    headers = {
      "Content-Type": "application/json",
      # Pass in our api key
      "Authorization": f"Bearer {userdata.get('OPEN_API_KEY')}"
    }

    payload = {
      "model": "gpt-4o-mini",
      "messages": [
        {
          "role": "user",
          "content": [
            {
              "type": "text",
              "text": f"{backgroundInfo}. Now here is the text for the wiki page: {context}"
            },
            {
              "type": "image_url",
              "image_url": {
                "url": encodedImage
              }
            },
          ]
        }
      ],
      "max_tokens": 500
    }

    response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)
    return response.json()['choices'][0]['message']['content']

# %%
def getPageAsText(url, getImages = True):
  # Fetch the webpage
  response = requests.get(url)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser')

  # Find all a tags and add a note saying where they link to
  pageLinks = soup.find_all('a')

  for link in pageLinks:
    href = link.get('href')
    prefixes = ['/umiacs/index.php', '#', 'https://wiki.umiacs.umd.edu/umiacs/index.php', 'javascript']
    if href and not href.lower().startswith(tuple(prefixes)):
      p_tag = soup.new_tag('p')
      p_tag.string = link.getText() + f"(The prior text links to {href})"
      link.replace_with(p_tag)

  # Find all h1 tags and mark them so we can chunk by headers if needed
  hTags = soup.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6'])

  for tag in hTags:
    tag.string = f"\uFE17{tag.string}"

  if getImages:
    # Find all image tags and convert the images to text
    images = soup.find_all('img')
    for img in images:
        modified_html = soup.find('body').get_text()
        img_url = img.get('src')

        # Ignore the footer image that appears on every page
        if img_url == '/umiacs/resources/assets/poweredby_mediawiki_88x31.png':
          continue

        # If the image URL is relative, we need to join it with the base URL
        if img_url.startswith('/'):
            img_url = requests.compat.urljoin(url, img_url)

        try:
            img_data = requests.get(img_url).content

            # Convert the image to Base64
            img_base64 = base64.b64encode(img_data).decode('utf-8')
            img_format = img_url.split('.')[-1]  # Get the file extension
            base64_src = f'data:image/{img_format};base64,{img_base64}'
            imageAsText = describeImage(modified_html, base64_src)

            # Replace the img tag with the description from GPT
            p_tag = soup.new_tag('p')
            p_tag.string = imageAsText

            # Replace the <img> tag with the new <p> tag
            img.replace_with(p_tag)

        except Exception as e:
            print(f"Error processing image {img_url}: {e}")

  modified_html = soup.find('body').get_text()

  # Return all the text surrounded by two unicode characters to make it easier to find where each page starts/ends
  return (f"\u3018The following url: {url} contains the following information: {modified_html}\u3019")

# %%
def base64ToFile(imageString):
  # Finds the text between the unicode starting and ending characters
  removeUnicode = imageString.split("\u3016")[1].split("\u3017")[0]
  # Finds the format of the image
  format = removeUnicode.split('data:image/')[1].split(';')[0]
  # Finds the base64 text of the iamge
  base64Text = removeUnicode.split(";base64,")[1]
  imgData = base64.b64decode(base64Text)

  # Step 2: Write the bytes to a file
  with open(f'output_image.{format}', 'wb') as imgFile:  # You can change the file extension as needed
      imgFile.write(imgData)

  print("Image saved successfully!")

# %%
open('scrapedText.txt', 'w').close()

# Here we parse through all the pages on the wiki and write the info to a file

# This cannot parse dynamic pages, you have to use some other library like Selenium

i = 1
for link in pageset:
    print("Parsing Link " + str(i)  + " url is " + str(link))
    i += 1
    with open('scrapedText.txt', 'a') as file:
        text = getPageAsText(link)
        file.write(text)
# Out:
# Parsing Link 1url is https://wiki.umiacs.umd.edu/umiacs/index.php/OBJ/WebHosting
# Parsing Link 2url is https://wiki.umiacs.umd.edu/umiacs/index.php/BarracudaSpamFirewall/Scoring
# Parsing Link 3url is https://wiki.umiacs.umd.edu/umiacs/index.php/Singularity
# Parsing Link 4url is https://wiki.umiacs.umd.edu/umiacs/index.php/PythonVirtualEnv
# Parsing Link 5url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/ConferenceRooms/HuddleRoom
# Parsing Link 6url is https://wiki.umiacs.umd.edu/umiacs/index.php/Main_Page
# Parsing Link 7url is https://wiki.umiacs.umd.edu/umiacs/index.php/Network/VPN/Linux
# Parsing Link 8url is https://wiki.umiacs.umd.edu/umiacs/index.php/Modules
# Parsing Link 9url is https://wiki.umiacs.umd.edu/umiacs/index.php/ConferenceRooms/ATL3100C
# Parsing Link 10url is https://wiki.umiacs.umd.edu/umiacs/index.php/CollaboratorAccount
# Parsing Link 11url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/ConferenceRooms/Moderation
# Parsing Link 12url is https://wiki.umiacs.umd.edu/umiacs/index.php/Google_Drive/Migrating_from_Backup_and_Sync_to_Drive_for_Desktop
# Parsing Link 13url is https://wiki.umiacs.umd.edu/umiacs/index.php/Backups
# Parsing Link 14url is https://wiki.umiacs.umd.edu/umiacs/index.php/BarracudaSpamFirewall/SearchingQuarantine
# Parsing Link 15url is https://wiki.umiacs.umd.edu/umiacs/index.php/OptLocal
# Parsing Link 16url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe
# Parsing Link 17url is https://wiki.umiacs.umd.edu/umiacs/index.php/Nexus/Tron
# Parsing Link 18url is https://wiki.umiacs.umd.edu/umiacs/index.php/NASUsers
# Parsing Link 19url is https://wiki.umiacs.umd.edu/umiacs/index.php/JavaDisableBrowser
# Parsing Link 20url is https://wiki.umiacs.umd.edu/umiacs/index.php/CUDA
# Parsing Link 21url is https://wiki.umiacs.umd.edu/umiacs/index.php/CoreServices
# Parsing Link 22url is https://wiki.umiacs.umd.edu/umiacs/index.php/DigitalLoanerForm
# Parsing Link 23url is https://wiki.umiacs.umd.edu/umiacs/index.php/EmailMigration/SelfMigration
# Parsing Link 24url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe_PacketFence_Network
# Parsing Link 25url is https://wiki.umiacs.umd.edu/umiacs/index.php/Caffe
# Parsing Link 26url is https://wiki.umiacs.umd.edu/umiacs/index.php/CompromisedPasswordFiltering
# Parsing Link 27url is https://wiki.umiacs.umd.edu/umiacs/index.php/SSH/Keys
# Parsing Link 28url is https://wiki.umiacs.umd.edu/umiacs/index.php/Security
# Parsing Link 29url is https://wiki.umiacs.umd.edu/umiacs/index.php/FTP/OSX/Finder
# Parsing Link 30url is https://wiki.umiacs.umd.edu/umiacs/index.php/ConferenceRooms/ATL3100A
# Parsing Link 31url is https://wiki.umiacs.umd.edu/umiacs/index.php/R
# Parsing Link 32url is https://wiki.umiacs.umd.edu/umiacs/index.php/UserReport
# Parsing Link 33url is https://wiki.umiacs.umd.edu/umiacs/index.php/Snapshots
# Parsing Link 34url is https://wiki.umiacs.umd.edu/umiacs/index.php/Google_Drive
# Parsing Link 35url is https://wiki.umiacs.umd.edu/umiacs/index.php/Accounts/Collaborator
# Parsing Link 36url is https://wiki.umiacs.umd.edu/umiacs/index.php/Services/Compute/HPC
# Parsing Link 37url is https://wiki.umiacs.umd.edu/umiacs/index.php/PerlDevelEnvironment
# Parsing Link 38url is https://wiki.umiacs.umd.edu/umiacs/index.php/Mattermost
# Parsing Link 39url is https://wiki.umiacs.umd.edu/umiacs/index.php/Nexus/MBRC
# Parsing Link 40url is https://wiki.umiacs.umd.edu/umiacs/index.php/SLURM/Preemption
# Parsing Link 41url is https://wiki.umiacs.umd.edu/umiacs/index.php/OrderingEquipment
# Parsing Link 42url is https://login.umiacs.umd.edu/auth/realms/UMIACS/protocol/openid-connect/auth?response_type=code&redirect_uri=https%3A%2F%2Fwiki.umiacs.umd.edu%2Fumiacs%2Findex.php%2FSpecial%3APluggableAuthLogin&client_id=wiki_umiacs_production&nonce=6175283e034dae006a49975d26822191&state=8d8bb6e29b71e61e531c315e88580b29&scope=openid+profile+email+openid
# Parsing Link 43url is https://wiki.umiacs.umd.edu/umiacs/index.php/SSH_Jumphosts
# Parsing Link 44url is https://wiki.umiacs.umd.edu/umiacs/index.php/HelpDesk
# Parsing Link 45url is https://wiki.umiacs.umd.edu/umiacs/index.php/Windows_10_Servicing
# Parsing Link 46url is https://wiki.umiacs.umd.edu/umiacs/index.php/Email/Barracuda
# Parsing Link 47url is https://wiki.umiacs.umd.edu/umiacs/index.php/Network/VPN/Mobile
# Parsing Link 48url is https://wiki.umiacs.umd.edu/umiacs/index.php/MailmanFAQ
# Parsing Link 49url is https://wiki.umiacs.umd.edu/umiacs/index.php/Ubuntu/SoftwareCenter
# Parsing Link 50url is https://wiki.umiacs.umd.edu/umiacs/index.php/Jekyll
# Parsing Link 51url is https://wiki.umiacs.umd.edu/umiacs/index.php/Mpich1sub.sh.e167
# Parsing Link 52url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe_Wired_Network
# Parsing Link 53url is https://wiki.umiacs.umd.edu/umiacs/index.php/Lamsub.sh.o127
# Parsing Link 54url is https://wiki.umiacs.umd.edu/umiacs/index.php/Nexus/Vulcan/GPUs
# Parsing Link 55url is https://wiki.umiacs.umd.edu/umiacs/index.php/Torch
# Parsing Link 56url is https://wiki.umiacs.umd.edu/umiacs/index.php/Services/CommonPool
# Parsing Link 57url is https://wiki.umiacs.umd.edu/umiacs/index.php/S3Clients
# Parsing Link 58url is https://wiki.umiacs.umd.edu/umiacs/index.php/Barracuda_Spam_Firewall
# Parsing Link 59url is https://wiki.umiacs.umd.edu/umiacs/index.php/RStudio
# Parsing Link 60url is https://wiki.umiacs.umd.edu/umiacs/index.php/Programming
# Parsing Link 61url is https://wiki.umiacs.umd.edu/umiacs/index.php/Nexus/GPUs
# Parsing Link 62url is https://wiki.umiacs.umd.edu/umiacs/index.php/Rclone
# Parsing Link 63url is https://wiki.umiacs.umd.edu/umiacs/index.php/Vtune
# Parsing Link 64url is https://wiki.umiacs.umd.edu/umiacs/index.php/MathematicaActivation
# Parsing Link 65url is https://wiki.umiacs.umd.edu/umiacs/index.php/IntelCompilers
# Parsing Link 66url is https://wiki.umiacs.umd.edu/umiacs/index.php/MacOSPrinting
# Parsing Link 67url is https://wiki.umiacs.umd.edu/umiacs/index.php/SFTP
# Parsing Link 68url is https://wiki.umiacs.umd.edu/umiacs/index.php/PrinterTroubleshooting
# Parsing Link 69url is https://wiki.umiacs.umd.edu/umiacs/index.php/SetGID
# Parsing Link 70url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/Mailroom
# Parsing Link 71url is https://wiki.umiacs.umd.edu/umiacs/index.php/Perl
# Parsing Link 72url is https://wiki.umiacs.umd.edu/umiacs/index.php/Service/Compute/Virtualization
# Parsing Link 73url is https://wiki.umiacs.umd.edu/umiacs/index.php/LDAP
# Parsing Link 74url is https://wiki.umiacs.umd.edu/umiacs/index.php/OBJ
# Parsing Link 75url is https://wiki.umiacs.umd.edu/umiacs/index.php/OpenCVVersions
# Parsing Link 76url is https://wiki.umiacs.umd.edu/umiacs/index.php/UbuntuPrinting
# Parsing Link 77url is https://wiki.umiacs.umd.edu/umiacs/index.php/Fixing_Stuck_Standing_Desk
# Parsing Link 78url is https://wiki.umiacs.umd.edu/umiacs/index.php/Network/VPN/Android
# Parsing Link 79url is https://wiki.umiacs.umd.edu/umiacs/index.php/Network/VPN/macOS
# Parsing Link 80url is https://wiki.umiacs.umd.edu/umiacs/index.php/WebSensitiveInformation
# Parsing Link 81url is https://wiki.umiacs.umd.edu/umiacs/index.php/SecureShell
# Parsing Link 82url is https://wiki.umiacs.umd.edu/umiacs/index.php/Nexus/Vulcan
# Parsing Link 83url is https://wiki.umiacs.umd.edu/umiacs/index.php/ServiceDeskMigration
# Parsing Link 84url is https://wiki.umiacs.umd.edu/umiacs/index.php/PrintingDoubleSidedUSB
# Parsing Link 85url is https://wiki.umiacs.umd.edu/umiacs/index.php/MongoDB
# Parsing Link 86url is https://wiki.umiacs.umd.edu/umiacs/index.php/ATL/ConferenceRooms
# Parsing Link 87url is https://wiki.umiacs.umd.edu/umiacs/index.php/Adobe
# Parsing Link 88url is https://wiki.umiacs.umd.edu/umiacs/index.php/RedHat
# Parsing Link 89url is https://wiki.umiacs.umd.edu/umiacs/index.php/SLURM/Priority
# Parsing Link 90url is https://wiki.umiacs.umd.edu/umiacs/index.php/UMIACS:General_disclaimer
# Parsing Link 91url is https://wiki.umiacs.umd.edu/umiacs/index.php/ClassAccounts/Manage
# Parsing Link 92url is https://wiki.umiacs.umd.edu/umiacs/index.php/MediaSanitization
# Parsing Link 93url is https://wiki.umiacs.umd.edu/umiacs/index.php/Phishing
# Parsing Link 94url is https://wiki.umiacs.umd.edu/umiacs/index.php/Nexus/GAMMA
# Parsing Link 95url is https://wiki.umiacs.umd.edu/umiacs/index.php/UMobj
# Parsing Link 96url is https://wiki.umiacs.umd.edu/umiacs/index.php/CIFS
# Parsing Link 97url is https://wiki.umiacs.umd.edu/umiacs/index.php/BitLocker/PersonalUse
# Error processing image https://wiki.umiacs.umd.edu/umiacs/images/3/34/Cleanup3.png: 'choices'
# Error processing image https://wiki.umiacs.umd.edu/umiacs/images/a/ad/Cleanup4.png: 'choices'
# Parsing Link 98url is https://wiki.umiacs.umd.edu/umiacs/index.php/Ubuntu
# Parsing Link 99url is https://wiki.umiacs.umd.edu/umiacs/index.php/WindowsPrinting
# Parsing Link 100url is https://wiki.umiacs.umd.edu/umiacs/index.php/CDebuggers
# Parsing Link 101url is https://wiki.umiacs.umd.edu/umiacs/index.php/Setting_File_Permissions_in_Windows
# Parsing Link 102url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/Faxing
# Parsing Link 103url is https://wiki.umiacs.umd.edu/umiacs/index.php/Remote_Desktop
# Parsing Link 104url is https://wiki.umiacs.umd.edu/umiacs/index.php/WindowsPrintingUMIACS
# Parsing Link 105url is https://wiki.umiacs.umd.edu/umiacs/index.php/Windows_Account_Migration_March_2018
# Parsing Link 106url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/ConferenceRooms/Reserve
# Parsing Link 107url is https://wiki.umiacs.umd.edu/umiacs/index.php/WindowsDisplayModes
# Parsing Link 108url is https://wiki.umiacs.umd.edu/umiacs/index.php/Services/Support
# Parsing Link 109url is https://wiki.umiacs.umd.edu/umiacs/index.php/Services/Compute/LabSpecific
# Parsing Link 110url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/ConferenceRooms/AutoAccept
# Parsing Link 111url is https://wiki.umiacs.umd.edu/umiacs/index.php/Nexus/MC2
# Parsing Link 112url is https://wiki.umiacs.umd.edu/umiacs/index.php/JavaVersions
# Parsing Link 113url is https://wiki.umiacs.umd.edu/umiacs/index.php/LinuxFAQ
# Parsing Link 114url is https://wiki.umiacs.umd.edu/umiacs/index.php/HPC
# Parsing Link 115url is https://wiki.umiacs.umd.edu/umiacs/index.php/Special:AllPages
# Parsing Link 116url is https://wiki.umiacs.umd.edu/umiacs/index.php/Apptainer
# Parsing Link 117url is https://wiki.umiacs.umd.edu/umiacs/index.php/RevisionControl
# Parsing Link 118url is https://wiki.umiacs.umd.edu/umiacs/index.php/ConferenceRooms/ATL3100D
# Parsing Link 119url is https://wiki.umiacs.umd.edu/umiacs/index.php/Malware/virus_removal
# Parsing Link 120url is https://wiki.umiacs.umd.edu/umiacs/index.php/Web
# Parsing Link 121url is https://wiki.umiacs.umd.edu/umiacs/index.php/GettingStarted
# Parsing Link 122url is https://wiki.umiacs.umd.edu/umiacs/index.php/Orders
# Parsing Link 123url is https://wiki.umiacs.umd.edu/umiacs/index.php/Publishing_Data
# Parsing Link 124url is https://wiki.umiacs.umd.edu/umiacs/index.php/GitLab
# Parsing Link 125url is https://wiki.umiacs.umd.edu/umiacs/index.php/Compute/DataLocality
# Parsing Link 126url is https://wiki.umiacs.umd.edu/umiacs/index.php/SCM
# Parsing Link 127url is https://wiki.umiacs.umd.edu/umiacs/index.php/SecureCopy
# Parsing Link 128url is https://wiki.umiacs.umd.edu/umiacs/index.php/EmailMigration
# Parsing Link 129url is https://wiki.umiacs.umd.edu/umiacs/index.php/MBRC
# Parsing Link 130url is https://wiki.umiacs.umd.edu/umiacs/index.php/Lamsub.sh.e127
# Parsing Link 131url is https://wiki.umiacs.umd.edu/umiacs/index.php/NASProjects
# Parsing Link 132url is https://wiki.umiacs.umd.edu/umiacs/index.php/Services/Data
# Parsing Link 133url is https://wiki.umiacs.umd.edu/umiacs/index.php/ConferenceRooms/ATL
# Parsing Link 134url is https://wiki.umiacs.umd.edu/umiacs/index.php/Tmux
# Parsing Link 135url is https://wiki.umiacs.umd.edu/umiacs/index.php/Services/Logistics
# Parsing Link 136url is https://wiki.umiacs.umd.edu/umiacs/index.php/SecureShell/MFA
# Parsing Link 137url is https://wiki.umiacs.umd.edu/umiacs/index.php/Tensorflow
# Parsing Link 138url is https://wiki.umiacs.umd.edu/umiacs/index.php/ConferenceRooms/TouchPanel
# Parsing Link 139url is https://wiki.umiacs.umd.edu/umiacs/index.php/Services
# Parsing Link 140url is https://wiki.umiacs.umd.edu/umiacs/index.php/ConferenceRooms
# Parsing Link 141url is https://wiki.umiacs.umd.edu/umiacs/index.php/SLURM/ArrayJobs
# Parsing Link 142url is https://wiki.umiacs.umd.edu/umiacs/index.php/Services/EMail
# Parsing Link 143url is https://wiki.umiacs.umd.edu/umiacs/index.php/Unix_groups
# Parsing Link 144url is https://wiki.umiacs.umd.edu/umiacs/index.php/VPN/OSX
# Parsing Link 145url is https://wiki.umiacs.umd.edu/umiacs/index.php/SecGroups
# Parsing Link 146url is https://wiki.umiacs.umd.edu/umiacs/index.php/ApplicationResource
# Parsing Link 147url is https://wiki.umiacs.umd.edu/umiacs/index.php/Network/VPN/Ivanti
# Parsing Link 148url is https://wiki.umiacs.umd.edu/umiacs/index.php/SSH/MFA
# Parsing Link 149url is https://wiki.umiacs.umd.edu/umiacs/index.php/Branding
# Parsing Link 150url is https://wiki.umiacs.umd.edu/umiacs/index.php/Tron
# Parsing Link 151url is https://wiki.umiacs.umd.edu/umiacs/index.php/FileTransferProtocol
# Parsing Link 152url is https://wiki.umiacs.umd.edu/umiacs/index.php/Creating_service_admin_user_on_OSX
# Parsing Link 153url is https://wiki.umiacs.umd.edu/umiacs/index.php/UMIACS_Account
# Parsing Link 154url is https://wiki.umiacs.umd.edu/umiacs/index.php/Stow
# Parsing Link 155url is https://wiki.umiacs.umd.edu/umiacs/index.php/Microsoft_Office_Activation
# Parsing Link 156url is https://wiki.umiacs.umd.edu/umiacs/index.php/JavaDevelEnvironment
# Parsing Link 157url is https://wiki.umiacs.umd.edu/umiacs/index.php/Password
# Parsing Link 158url is https://wiki.umiacs.umd.edu/umiacs/index.php/URL
# Parsing Link 159url is https://wiki.umiacs.umd.edu/umiacs/index.php/WindowsServicing
# Parsing Link 160url is https://wiki.umiacs.umd.edu/umiacs/index.php/SSHFileTransferProtocol
# Parsing Link 161url is https://wiki.umiacs.umd.edu/umiacs/index.php/Working_with_External_Collaborators
# Parsing Link 162url is https://wiki.umiacs.umd.edu/umiacs/index.php/BarracudaSpamFirewall/QuarantinePassthrough
# Parsing Link 163url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/ConferenceRooms/Solstice
# Parsing Link 164url is https://wiki.umiacs.umd.edu/umiacs/index.php/Windows_Personal_Backups
# Parsing Link 165url is https://wiki.umiacs.umd.edu/umiacs/index.php/FTP
# Parsing Link 166url is https://wiki.umiacs.umd.edu/umiacs/index.php/UNIXPrinting
# Parsing Link 167url is https://wiki.umiacs.umd.edu/umiacs/index.php/CBCB
# Parsing Link 168url is https://wiki.umiacs.umd.edu/umiacs/index.php/WebCrawling
# Parsing Link 169url is https://wiki.umiacs.umd.edu/umiacs/index.php/MPATH
# Parsing Link 170url is https://wiki.umiacs.umd.edu/umiacs/index.php/Wireless
# Parsing Link 171url is https://wiki.umiacs.umd.edu/umiacs/index.php/OpenLAB
# Parsing Link 172url is https://wiki.umiacs.umd.edu/umiacs/index.php/Network
# Parsing Link 173url is https://wiki.umiacs.umd.edu/umiacs/index.php/PerlLocalLib
# Parsing Link 174url is https://wiki.umiacs.umd.edu/umiacs/index.php/Kerberos
# Parsing Link 175url is https://wiki.umiacs.umd.edu/umiacs/index.php/Subversion
# Parsing Link 176url is https://wiki.umiacs.umd.edu/umiacs/index.php/Network/VPN/MFA
# Parsing Link 177url is https://wiki.umiacs.umd.edu/umiacs/index.php/Outage
# Parsing Link 178url is https://wiki.umiacs.umd.edu/umiacs/index.php/Google_Drive/Backup_and_Sync
# Parsing Link 179url is https://wiki.umiacs.umd.edu/umiacs/index.php/CMake
# Parsing Link 180url is https://wiki.umiacs.umd.edu/umiacs/index.php/CML
# Parsing Link 181url is https://wiki.umiacs.umd.edu/umiacs/index.php/Nexus/CLIP
# Parsing Link 182url is https://wiki.umiacs.umd.edu/umiacs/index.php/NightlyBackups
# Parsing Link 183url is https://wiki.umiacs.umd.edu/umiacs/index.php/ActiveDirectory
# Parsing Link 184url is https://wiki.umiacs.umd.edu/umiacs/index.php/Services/Collaboration
# Parsing Link 185url is https://wiki.umiacs.umd.edu/umiacs/index.php/SLURM/JobSubmission
# Parsing Link 186url is https://wiki.umiacs.umd.edu/umiacs/index.php/Network/VPN/OSX
# Parsing Link 187url is https://wiki.umiacs.umd.edu/umiacs/index.php/ConferenceRooms/Recording
# Parsing Link 188url is https://wiki.umiacs.umd.edu/umiacs/index.php/Network/VPN/Troubleshooting
# Parsing Link 189url is https://wiki.umiacs.umd.edu/umiacs/index.php/Lamsub2.sh
# Parsing Link 190url is https://wiki.umiacs.umd.edu/umiacs/index.php/SLURM
# Parsing Link 191url is https://wiki.umiacs.umd.edu/umiacs/index.php/Windows/LaptopSupport
# Parsing Link 192url is https://wiki.umiacs.umd.edu/umiacs/index.php/Services/OnSite
# Parsing Link 193url is https://wiki.umiacs.umd.edu/umiacs/index.php/Screen
# Parsing Link 194url is https://wiki.umiacs.umd.edu/umiacs/index.php/Matlab
# Parsing Link 195url is https://wiki.umiacs.umd.edu/umiacs/index.php/UpdatingMozillaSoftware
# Parsing Link 196url is https://wiki.umiacs.umd.edu/umiacs/index.php/Umiacs_Public_Printers
# Parsing Link 197url is https://wiki.umiacs.umd.edu/umiacs/index.php/Automounter
# Parsing Link 198url is https://wiki.umiacs.umd.edu/umiacs/index.php/Mpich1sub.sh
# Parsing Link 199url is https://wiki.umiacs.umd.edu/umiacs/index.php/Network/VPN
# Parsing Link 200url is https://wiki.umiacs.umd.edu/umiacs/index.php/OSSupport
# Parsing Link 201url is https://wiki.umiacs.umd.edu/umiacs/index.php/FTP/macOS/Finder
# Parsing Link 202url is https://wiki.umiacs.umd.edu/umiacs/index.php/RHEL7
# Parsing Link 203url is https://wiki.umiacs.umd.edu/umiacs/index.php/BashForWindows10
# Parsing Link 204url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/ConferenceRooms/List
# Parsing Link 205url is https://wiki.umiacs.umd.edu/umiacs/index.php/Python
# Parsing Link 206url is https://wiki.umiacs.umd.edu/umiacs/index.php/BarracudaSpamFirewall
# Parsing Link 207url is https://wiki.umiacs.umd.edu/umiacs/index.php/WindowsSubsystemForLinux
# Parsing Link 208url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/ConferenceRooms/TouchPanel
# Parsing Link 209url is https://wiki.umiacs.umd.edu/umiacs/index.php/AlternativePickup
# Parsing Link 210url is https://wiki.umiacs.umd.edu/umiacs/index.php/ConferenceRooms/Solstice
# Parsing Link 211url is https://wiki.umiacs.umd.edu/umiacs/index.php/Nexus/Apptainer
# Parsing Link 212url is https://wiki.umiacs.umd.edu/umiacs/index.php/Gurobi
# Parsing Link 213url is https://wiki.umiacs.umd.edu/umiacs/index.php/WindowsJuniperVPN
# Parsing Link 214url is https://wiki.umiacs.umd.edu/umiacs/index.php/Podman
# Parsing Link 215url is https://wiki.umiacs.umd.edu/umiacs/index.php/Snapshots:Example
# Parsing Link 216url is https://wiki.umiacs.umd.edu/umiacs/index.php/Mpich1sub.sh.o167
# Parsing Link 217url is https://wiki.umiacs.umd.edu/umiacs/index.php/VPN
# Parsing Link 218url is https://wiki.umiacs.umd.edu/umiacs/index.php/Umask
# Parsing Link 219url is https://wiki.umiacs.umd.edu/umiacs/index.php/Services/Web
# Parsing Link 220url is https://wiki.umiacs.umd.edu/umiacs/index.php/ClassAccounts
# Parsing Link 221url is https://wiki.umiacs.umd.edu/umiacs/index.php/SearchingQuarantine
# Parsing Link 222url is https://wiki.umiacs.umd.edu/umiacs/index.php/InputMethodEditors
# Parsing Link 223url is https://wiki.umiacs.umd.edu/umiacs/index.php/EnvironmentalVariables
# Parsing Link 224url is https://wiki.umiacs.umd.edu/umiacs/index.php/Lamsub.sh
# Parsing Link 225url is https://wiki.umiacs.umd.edu/umiacs/index.php/VPN/Windows
# Parsing Link 226url is https://wiki.umiacs.umd.edu/umiacs/index.php/(N/A)Network/VPN/OSX
# Parsing Link 227url is https://wiki.umiacs.umd.edu/umiacs/index.php/Shell
# Parsing Link 228url is https://wiki.umiacs.umd.edu/umiacs/index.php/MailingLists
# Parsing Link 229url is https://wiki.umiacs.umd.edu/umiacs/index.php/WindowsPermissions
# Parsing Link 230url is https://wiki.umiacs.umd.edu/umiacs/index.php/Quota
# Parsing Link 231url is https://wiki.umiacs.umd.edu/umiacs/index.php/WebSpace
# Parsing Link 232url is https://wiki.umiacs.umd.edu/umiacs/index.php/LabFacilities
# Parsing Link 233url is https://wiki.umiacs.umd.edu/umiacs/index.php/OBJbox
# Parsing Link 234url is https://wiki.umiacs.umd.edu/umiacs/index.php/WindowsPython
# Parsing Link 235url is https://wiki.umiacs.umd.edu/umiacs/index.php/NAS
# Parsing Link 236url is https://wiki.umiacs.umd.edu/umiacs/index.php/Nexus/CML
# Parsing Link 237url is https://wiki.umiacs.umd.edu/umiacs/index.php/UMIACS:Privacy_policy
# Parsing Link 238url is https://wiki.umiacs.umd.edu/umiacs/index.php/Show_available_nodes
# Parsing Link 239url is https://wiki.umiacs.umd.edu/umiacs/index.php/Services/Compute/UserSupported
# Parsing Link 240url is https://wiki.umiacs.umd.edu/umiacs/index.php/RHELDisplayModes
# Parsing Link 241url is https://wiki.umiacs.umd.edu/umiacs/index.php/Datasets
# Parsing Link 242url is https://wiki.umiacs.umd.edu/umiacs/index.php/SSH
# Parsing Link 243url is https://wiki.umiacs.umd.edu/umiacs/index.php/Tcsh
# Parsing Link 244url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/ConferenceRooms/Zoom
# Parsing Link 245url is https://wiki.umiacs.umd.edu/umiacs/index.php/CUPS
# Parsing Link 246url is https://wiki.umiacs.umd.edu/umiacs/index.php/ConferenceRooms/IRB
# Parsing Link 247url is https://wiki.umiacs.umd.edu/umiacs/index.php/UMIACS:About
# Parsing Link 248url is https://wiki.umiacs.umd.edu/umiacs/index.php/PATH
# Parsing Link 249url is https://wiki.umiacs.umd.edu/umiacs/index.php/Nexus/Gamma
# Parsing Link 250url is https://wiki.umiacs.umd.edu/umiacs/index.php/MacOSDisplayModes
# Parsing Link 251url is https://wiki.umiacs.umd.edu/umiacs/index.php/Clear_Cache
# Parsing Link 252url is https://wiki.umiacs.umd.edu/umiacs/index.php/UMIACS_Public_Printers
# Parsing Link 253url is https://wiki.umiacs.umd.edu/umiacs/index.php/LANDesk
# Parsing Link 254url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/ConferenceRooms/Recording
# Parsing Link 255url is https://wiki.umiacs.umd.edu/umiacs/index.php/Network/VPN/IOS
# Parsing Link 256url is https://wiki.umiacs.umd.edu/umiacs/index.php/Archives
# Parsing Link 257url is https://wiki.umiacs.umd.edu/umiacs/index.php/BitLocker
# Parsing Link 258url is https://wiki.umiacs.umd.edu/umiacs/index.php/FTP/Windows/Explorer
# Parsing Link 259url is https://wiki.umiacs.umd.edu/umiacs/index.php/NautilusThumbnails
# Parsing Link 260url is https://wiki.umiacs.umd.edu/umiacs/index.php/Perl/Environment
# Parsing Link 261url is https://wiki.umiacs.umd.edu/umiacs/index.php/SecureShellTunneling
# Parsing Link 262url is https://wiki.umiacs.umd.edu/umiacs/index.php/VS_Code
# Parsing Link 263url is https://wiki.umiacs.umd.edu/umiacs/index.php/Network/Troubleshooting/DNS
# Parsing Link 264url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/ConferenceRooms
# Parsing Link 265url is https://wiki.umiacs.umd.edu/umiacs/index.php/SLURM/JobStatus
# Parsing Link 266url is https://wiki.umiacs.umd.edu/umiacs/index.php/Intranet
# Parsing Link 267url is https://wiki.umiacs.umd.edu/umiacs/index.php/Java
# Parsing Link 268url is https://wiki.umiacs.umd.edu/umiacs/index.php/RHEL
# Parsing Link 269url is https://wiki.umiacs.umd.edu/umiacs/index.php/Windows_Activation
# Parsing Link 270url is https://wiki.umiacs.umd.edu/umiacs/index.php/Vulcan
# Parsing Link 271url is https://wiki.umiacs.umd.edu/umiacs/index.php/NAGWareCompiler
# Parsing Link 272url is https://wiki.umiacs.umd.edu/umiacs/index.php/CCompilers
# Parsing Link 273url is https://wiki.umiacs.umd.edu/umiacs/index.php/Google_Drive/Drive_for_Desktop
# Parsing Link 274url is https://wiki.umiacs.umd.edu/umiacs/index.php/MFA
# Parsing Link 275url is https://wiki.umiacs.umd.edu/umiacs/index.php/Mpich1.csh
# Parsing Link 276url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/ConferenceRooms/View
# Parsing Link 277url is https://wiki.umiacs.umd.edu/umiacs/index.php/LaTeX
# Parsing Link 278url is https://wiki.umiacs.umd.edu/umiacs/index.php/Printing
# Parsing Link 279url is https://wiki.umiacs.umd.edu/umiacs/index.php/Mathematica
# Parsing Link 280url is https://wiki.umiacs.umd.edu/umiacs/index.php/Services/EquipmentLoans
# Parsing Link 281url is https://wiki.umiacs.umd.edu/umiacs/index.php/Creating_service_admin_user_on_macOS
# Parsing Link 282url is https://wiki.umiacs.umd.edu/umiacs/index.php/Docker
# Parsing Link 283url is https://wiki.umiacs.umd.edu/umiacs/index.php/MalwareRecovery
# Parsing Link 284url is https://wiki.umiacs.umd.edu/umiacs/index.php/EuclidCluster
# Parsing Link 285url is https://wiki.umiacs.umd.edu/umiacs/index.php/SLURM/ClusterStatus
# Parsing Link 286url is https://wiki.umiacs.umd.edu/umiacs/index.php/PrinterQueueNaming
# Parsing Link 287url is https://wiki.umiacs.umd.edu/umiacs/index.php/IOSJuniperVPN
# Parsing Link 288url is https://wiki.umiacs.umd.edu/umiacs/index.php/Obj_Website
# Parsing Link 289url is https://wiki.umiacs.umd.edu/umiacs/index.php/WindowsMigration
# Parsing Link 290url is https://wiki.umiacs.umd.edu/umiacs/index.php/ContentManagement
# Parsing Link 291url is https://wiki.umiacs.umd.edu/umiacs/index.php/UsrLocal
# Parsing Link 292url is https://wiki.umiacs.umd.edu/umiacs/index.php/NFShomes
# Parsing Link 293url is https://wiki.umiacs.umd.edu/umiacs/index.php/Network/Troubleshooting
# Parsing Link 294url is https://wiki.umiacs.umd.edu/umiacs/index.php/BashForWindows
# Parsing Link 295url is https://wiki.umiacs.umd.edu/umiacs/index.php/SetUID
# Parsing Link 296url is https://wiki.umiacs.umd.edu/umiacs/index.php/Duo
# Parsing Link 297url is https://wiki.umiacs.umd.edu/umiacs/index.php/MailmanListAdmin
# Parsing Link 298url is https://wiki.umiacs.umd.edu/umiacs/index.php/NFS
# Parsing Link 299url is https://wiki.umiacs.umd.edu/umiacs/index.php/Jira
# Parsing Link 300url is https://wiki.umiacs.umd.edu/umiacs/index.php/Network/VPN/Ubuntu
# Parsing Link 301url is https://wiki.umiacs.umd.edu/umiacs/index.php/Network/VPN/Windows
# Parsing Link 302url is https://wiki.umiacs.umd.edu/umiacs/index.php/OSXPrinting
# Parsing Link 303url is https://wiki.umiacs.umd.edu/umiacs/index.php/VScode
# Parsing Link 304url is https://wiki.umiacs.umd.edu/umiacs/index.php/ConferenceRooms/ATL3373
# Parsing Link 305url is https://wiki.umiacs.umd.edu/umiacs/index.php/Nexus/CBCB
# Parsing Link 306url is https://wiki.umiacs.umd.edu/umiacs/index.php/KVM
# Parsing Link 307url is https://wiki.umiacs.umd.edu/umiacs/index.php/Services/Compute
# Parsing Link 308url is https://wiki.umiacs.umd.edu/umiacs/index.php/Windows
# Parsing Link 309url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/ConferenceRooms/Moderated
# Parsing Link 310url is https://wiki.umiacs.umd.edu/umiacs/index.php/AddingUMIACSCertificateAuthority
# Parsing Link 311url is https://wiki.umiacs.umd.edu/umiacs/index.php/PGICompilers
# Parsing Link 312url is https://wiki.umiacs.umd.edu/umiacs/index.php/VPN/PulseSecure
# Parsing Link 313url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/ConferenceRooms/Solstice/Solstice_App
# Parsing Link 314url is https://wiki.umiacs.umd.edu/umiacs/index.php/QuICS
# Parsing Link 315url is https://wiki.umiacs.umd.edu/umiacs/index.php/Visual_Studio
# Parsing Link 316url is https://wiki.umiacs.umd.edu/umiacs/index.php/UNIXDataPolicies
# Parsing Link 317url is https://wiki.umiacs.umd.edu/umiacs/index.php/Bash
# Parsing Link 318url is https://wiki.umiacs.umd.edu/umiacs/index.php/OSXJuniperVPN
# Parsing Link 319url is https://wiki.umiacs.umd.edu/umiacs/index.php/Accounts
# Parsing Link 320url is https://wiki.umiacs.umd.edu/umiacs/index.php/SCP
# Parsing Link 321url is https://wiki.umiacs.umd.edu/umiacs/index.php/Data_Transfer
# Parsing Link 322url is https://wiki.umiacs.umd.edu/umiacs/index.php/MonthlyMaintenanceWindow
# Parsing Link 323url is https://wiki.umiacs.umd.edu/umiacs/index.php/Data_Compression_/_Archival
# Parsing Link 324url is https://wiki.umiacs.umd.edu/umiacs/index.php/Windows_Patch_Management
# Parsing Link 325url is https://wiki.umiacs.umd.edu/umiacs/index.php/MFA/Duo_Recovery
# Parsing Link 326url is https://wiki.umiacs.umd.edu/umiacs/index.php/LocalDataStorage
# Parsing Link 327url is https://wiki.umiacs.umd.edu/umiacs/index.php/Nexus
# Parsing Link 328url is https://wiki.umiacs.umd.edu/umiacs/index.php/Email
# Parsing Link 329url is https://wiki.umiacs.umd.edu/umiacs/index.php/ConferenceRooms/Zoom
# Parsing Link 330url is https://wiki.umiacs.umd.edu/umiacs/index.php/UMobj/Example
# Parsing Link 331url is https://wiki.umiacs.umd.edu/umiacs/index.php/ComputationalResource
# Parsing Link 332url is https://wiki.umiacs.umd.edu/umiacs/index.php/Nexus/Accounts
# Parsing Link 333url is https://wiki.umiacs.umd.edu/umiacs/index.php/TSM
# Parsing Link 334url is https://wiki.umiacs.umd.edu/umiacs/index.php/Iribe/OfficeTV

# %%
externalLinksWithImage = ['https://wiki.umiacs.umd.edu/umiacs/index.php/BitLocker/PersonalUse',
                          'https://umd.service-now.com/itsupport?id=kb_article_view&sysparm_article=KB0013664']
externalLinksWithoutImage = ['https://intranet.umiacs.umd.edu/',
                             'https://gitlab.umiacs.umd.edu/docker/jekyll-builder/-/blob/master/README.md?ref_type=heads',
                             'https://gitlab.umiacs.umd.edu/help/user/ssh.md',
                             'https://wiki.umiacs.umd.edu/clip/index.php/Main_Page',
                             'https://www.umiacs.umd.edu/about-us',
                             'https://helpdesk.cs.umd.edu/faq/iribe/equipment-peripherals.html',
                             'https://policies.umd.edu/miscellaneous-policies/university-of-maryland-policy-on-acceptable-use-of-information-technology-resources',
                             'https://gitlab.umiacs.umd.edu/derek/gpudocker/-/blob/master/README.md?ref_type=heads',
                             'https://umd.service-now.com/itsupport?id=kb_article_view&sysparm_article=KB0015077',
                             'https://umd.service-now.com/itsupport/?id=kb_article_view&sysparm_article=KB0011227',
                            ]

# %%
for link in externalLinksWithoutImage:
    with open('scrapedText.txt', 'a') as file:
        text = getPageAsText(link, getImages = False)
        file.write(text)

# %%
for link in externalLinksWithImage:
    with open('scrapedText.txt', 'a') as file:
        text = getPageAsText(link)
        file.write(text)
