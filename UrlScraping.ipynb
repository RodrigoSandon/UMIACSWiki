# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import time

def get_internal_links(url, domain_name, visited):
    """
    Given a URL, this function finds all links within the same domain.
    """
    try:
        # Request the URL content
        response = requests.get(url)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Failed to retrieve {url}: {e}")
        return []

    # Parse the page content
    soup = BeautifulSoup(response.text, 'html.parser')
    internal_links = []

    # Find all <a> tags with href attributes
    for link in soup.find_all('a', href=True):
        href = link.get('href')
        # Join relative URLs to form absolute URLs
        full_url = urljoin(url, href)
        # Check if the link is within the same domain
        if urlparse(full_url).netloc == domain_name and full_url not in visited:
            internal_links.append(full_url)

    return internal_links

def crawl_wiki(url, visited):
    """
    Recursively traverses links on a wiki page and prints internal links within the same domain.
    """
    domain_name = urlparse(url).netloc
    if url in visited:
        return

    print(f"Crawling: {url}")
    visited.add(url)

    # Get internal links on the page
    internal_links = get_internal_links(url, domain_name, visited)

    for link in internal_links:
        if link not in visited:
            crawl_wiki(link, visited)  # Recursive call

# Start URL
start_url = "https://criminalminds.fandom.com/wiki/Criminal_Minds_Wiki"
visited_urls = set()

# Begin crawling from the start URL
crawl_wiki(start_url, visited_urls)
# Out:
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds_Wiki
# Crawling: https://criminalminds.fandom.com
# Crawling: https://criminalminds.fandom.com/f
# Crawling: https://criminalminds.fandom.com/wiki/Special:Search
# Crawling: https://criminalminds.fandom.com/wiki/Special:AllPages
# Crawling: https://criminalminds.fandom.com/wiki/Special:Community
# Crawling: https://criminalminds.fandom.com/wiki/Special:AllMaps
# Crawling: https://criminalminds.fandom.com/Blog:Recent_posts
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds
# Crawling: https://criminalminds.fandom.com/wiki/Episodes
# Crawling: https://criminalminds.fandom.com/wiki/Season_Fourteen
# Crawling: https://criminalminds.fandom.com/wiki/Season_Thirteen
# Crawling: https://criminalminds.fandom.com/wiki/Season_Twelve
# Crawling: https://criminalminds.fandom.com/wiki/Season_Eleven
# Crawling: https://criminalminds.fandom.com/wiki/Season_Ten
# Crawling: https://criminalminds.fandom.com/wiki/Season_Nine
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_FBI_Personnel
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Minor_Characters
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Criminals
# Crawling: https://criminalminds.fandom.com/wiki/Making_Of
# Failed to retrieve https://criminalminds.fandom.com/wiki/Making_Of: 404 Client Error: Not Found for url: https://criminalminds.fandom.com/wiki/Making_Of
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Writers
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Directors
# Crawling: https://criminalminds.fandom.com/wiki/Behind_the_Scenes
# Crawling: https://criminalminds.fandom.com/wiki/Novels
# Crawling: https://criminalminds.fandom.com/wiki/Real_Life
# Failed to retrieve https://criminalminds.fandom.com/wiki/Real_Life: 404 Client Error: Not Found for url: https://criminalminds.fandom.com/wiki/Real_Life
# Crawling: https://criminalminds.fandom.com/wiki/Real_FBI_Agents
# Crawling: https://criminalminds.fandom.com/wiki/Real_Criminals
# Crawling: https://criminalminds.fandom.com/wiki/Real_Organizations
# Crawling: https://criminalminds.fandom.com/wiki/Category:Locations
# Crawling: https://criminalminds.fandom.com/wiki/Real_Weapons
# Crawling: https://criminalminds.fandom.com/wiki/Real_Drugs
# Crawling: https://criminalminds.fandom.com/wiki/Policies_%26_Guidelines
# Failed to retrieve https://criminalminds.fandom.com/wiki/Policies_%26_Guidelines: 404 Client Error: Not Found for url: https://criminalminds.fandom.com/wiki/Policies_%26_Guidelines
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds_Wiki:Rules
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds_Wiki:Blocking_Policy
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds_Wiki:Verifiability
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds_Wiki:Administrators
# Crawling: https://criminalminds.fandom.com/wiki/Message_Wall:Fearless_Prince
# Crawling: https://criminalminds.fandom.com/wiki/Message_Wall:Profiler10
# Crawling: https://criminalminds.fandom.com/wiki/Message_Wall:The_Man_of_Many_Names
# Crawling: https://criminalminds.fandom.com/wiki/Message_Wall:Fashionable101
# Crawling: https://criminalminds.fandom.com/wiki/Message_Wall:ONCEFan
# Crawling: https://criminalminds.fandom.com/wiki/Special:Leaderboard
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds_Wiki:Bulletin_Board
# Crawling: https://criminalminds.fandom.com/wiki/Template:Affiliates
# Crawling: https://criminalminds.fandom.com/wiki/Template:Affiliates?action=edit
# Crawling: https://criminalminds.fandom.com/wiki/Template:Affiliates?action=history
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?page=Template%3AAffiliates
# Crawling: https://criminalminds.fandom.com/wiki/Special:Tags
# Crawling: https://criminalminds.fandom.com/wiki/Special:RecentChanges?tagfilter=visualeditor
# Crawling: https://criminalminds.fandom.com/wiki/Special:RecentChanges
# Crawling: https://criminalminds.fandom.com/wiki/Special:SocialActivity
# Crawling: https://criminalminds.fandom.com/wiki/Special:NewFiles
# Crawling: https://criminalminds.fandom.com/wiki/File:Billy_Milligan_Victims.jpg
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds_Wiki?action=edit
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds_Wiki?action=history
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?page=Criminal+Minds+Wiki
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?logid=8724
# Crawling: https://criminalminds.fandom.com/wiki/User:Mvpl
# Crawling: https://criminalminds.fandom.com/wiki/User:Mvpl?action=edit
# Crawling: https://criminalminds.fandom.com/wiki/User:Mvpl?action=history
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?page=User%3AMvpl
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?logid=15720
# Crawling: https://criminalminds.fandom.com/wiki/User:Echo_Spy
# Crawling: https://criminalminds.fandom.com/wiki/User:Fearless_Prince?action=history
# Crawling: https://criminalminds.fandom.com/wiki/User:Fearless_Prince
# Crawling: https://criminalminds.fandom.com/wiki/Local_Sitemap
# Crawling: https://criminalminds.fandom.com/wiki/Local_Sitemap?namefrom=Benton+Farland
# Crawling: https://criminalminds.fandom.com/wiki/Local_Sitemap?namefrom=%27Til+Death+Do+Us+Part
# Crawling: https://criminalminds.fandom.com/wiki/%27Til_Death_Do_Us_Part
# Crawling: https://criminalminds.fandom.com/wiki/Category:Episodes
# Crawling: https://criminalminds.fandom.com/wiki/Category:Criminal_Minds
# Crawling: https://criminalminds.fandom.com/wiki/Category:Television
# Crawling: https://criminalminds.fandom.com/wiki/Category:Series
# Crawling: https://criminalminds.fandom.com/wiki/Category:Criminal_Minds_Wiki
# Crawling: https://criminalminds.fandom.com/wiki/Category:Browse
# Crawling: https://criminalminds.fandom.com/wiki/Category:Browse?action=history
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?page=Category%3ABrowse
# Crawling: https://criminalminds.fandom.com/wiki/Category_talk:Browse?action=edit&redlink=1
# Failed to retrieve https://criminalminds.fandom.com/wiki/Category_talk:Browse?action=edit&redlink=1: 404 Client Error: Not Found for url: https://criminalminds.fandom.com/wiki/Category_talk:Browse
# Crawling: https://criminalminds.fandom.com/wiki/Category:Browse?oldid=3073
# Crawling: https://criminalminds.fandom.com/wiki/User:Default
# Crawling: https://criminalminds.fandom.com/wiki/User:Default?action=history
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?page=User%3ADefault
# Crawling: https://criminalminds.fandom.com/wiki/Message_Wall:Default
# Crawling: https://criminalminds.fandom.com/wiki/User:Default?oldid=2695
# Crawling: https://criminalminds.fandom.com/wiki/Special:Contributions/Default
# Crawling: https://criminalminds.fandom.com/wiki/Special:
action=history
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?page=Category%3ASeasons
# Crawling: https://criminalminds.fandom.com/wiki/Category_talk:Seasons?action=edit&redlink=1
# Failed to retrieve https://criminalminds.fandom.com/wiki/Category_talk:Seasons?action=edit&redlink=1: 404 Client Error: Not Found for url: https://criminalminds.fandom.com/wiki/Category_talk:Seasons
# Crawling: https://criminalminds.fandom.com/wiki/Category:Seasons?diff=8725&oldid=8680
# Crawling: https://criminalminds.fandom.com/wiki/Category:Seasons?oldid=8680
# Crawling: https://criminalminds.fandom.com/wiki/User:Game_widow
# Crawling: https://criminalminds.fandom.com/wiki/Message_Wall:Game_widow
# Crawling: https://criminalminds.fandom.com/wiki/Special:Contributions/Game_widow
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log/block?page=User%3AGame+widow
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?logid=801
# Crawling: https://criminalminds.fandom.com/wiki/User:JoePlay
# Crawling: https://criminalminds.fandom.com/wiki/User:JoePlay?action=history
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?page=User%3AJoePlay
# Crawling: https://criminalminds.fandom.com/wiki/Message_Wall:JoePlay
# Crawling: https://criminalminds.fandom.com/wiki/User:JoePlay?oldid=134285
# Crawling: https://criminalminds.fandom.com/wiki/Special:Contributions/JoePlay
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log/block?page=User%3AJoePlay
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles/JoePlay
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?sort=img_timestamp&limit=50&asc=1&desc=&user=JoePlay
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?sort=img_timestamp&limit=50&asc=&desc=1&user=JoePlay
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log/JoePlay
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?logid=16353
# Crawling: https://criminalminds.fandom.com/wiki/File:Wiki-wordmark.png
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Beyond_Borders
# Crawling: https://criminalminds.fandom.com/wiki/Category:Spin-Offs
# Crawling: https://criminalminds.fandom.com/wiki/Category:Spin-Offs?action=history
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?page=Category%3ASpin-Offs
# Crawling: https://criminalminds.fandom.com/wiki/Category_talk:Spin-Offs?action=edit&redlink=1
# Failed to retrieve https://criminalminds.fandom.com/wiki/Category_talk:Spin-Offs?action=edit&redlink=1: 404 Client Error: Not Found for url: https://criminalminds.fandom.com/wiki/Category_talk:Spin-Offs
# Crawling: https://criminalminds.fandom.com/wiki/Category:Spin-Offs?oldid=80830
# Crawling: https://criminalminds.fandom.com/wiki/User:UnSub-Zero
# Crawling: https://criminalminds.fandom.com/wiki/Category:Users
# Crawling: https://criminalminds.fandom.com/wiki/Category:Users?action=history
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?page=Category%3AUsers
# Crawling: https://criminalminds.fandom.com/wiki/Category_talk:Users?action=edit&redlink=1
# Failed to retrieve https://criminalminds.fandom.com/wiki/Category_talk:Users?action=edit&redlink=1: 404 Client Error: Not Found for url: https://criminalminds.fandom.com/wiki/Category_talk:Users
# Crawling: https://criminalminds.fandom.com/wiki/Category:Users?diff=5719&oldid=4623
# Crawling: https://criminalminds.fandom.com/wiki/Category:Users?oldid=4623
# Crawling: https://criminalminds.fandom.com/wiki/User:Sec_1971
# Crawling: https://criminalminds.fandom.com/wiki/User:Sec_1971?action=edit
# Crawling: https://criminalminds.fandom.com/wiki/User:Sec_1971?action=history
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?page=User%3ASec+1971
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?logid=19132
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?logid=19131
# Crawling: https://criminalminds.fandom.com/wiki/User:Kirkburn
# Crawling: https://criminalminds.fandom.com/wiki/User:Kirkburn?action=history
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?page=User%3AKirkburn
# Crawling: https://criminalminds.fandom.com/wiki/Message_Wall:Kirkburn
# Crawling: https://criminalminds.fandom.com/wiki/User:Kirkburn?oldid=3632
# Crawling: https://criminalminds.fandom.com/wiki/Special:Contributions/Kirkburn
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log/block?page=User%3AKirkburn
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles/Kirkburn
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?sort=img_timestamp&limit=50&asc=1&desc=&user=Kirkburn
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?sort=img_timestamp&limit=50&asc=&desc=1&user=Kirkburn
# Crawling: https://criminalminds.fandom.com/wiki/File:TitleTemplate.png
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Suspect_Behavior
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_
ionable101
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?offset=20170909002851%7CGarcia_holding_Reid%27s_revolver.jpg&user=Fashionable101
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?user=Fashionable101
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?dir=prev&user=Fashionable101
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?dir=prev&offset=20200318202715%7CRichard_Stahl.png&user=Fashionable101
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?offset=20200505011013%7CRileyJenkins.jpg&user=Fashionable101
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?sort=img_timestamp&limit=50&asc=1&desc=&user=Fashionable101
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?offset=20200318202715%7CRichard_Stahl.png&user=Fashionable101&sort=img_timestamp&asc=1&desc=
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?user=Fashionable101&sort=img_timestamp&asc=1&desc=
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?dir=prev&user=Fashionable101&sort=img_timestamp&asc=1&desc=
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?dir=prev&offset=20170909002851%7CGarcia_holding_Reid%27s_revolver.jpg&user=Fashionable101&sort=img_timestamp&asc=1&desc=
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?offset=20170909000815%7CFoyet_M1911.jpg&user=Fashionable101&sort=img_timestamp&asc=1&desc=
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?sort=img_timestamp&limit=50&asc=&desc=1&user=Fashionable101
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?offset=20170909002851%7CGarcia_holding_Reid%27s_revolver.jpg&user=Fashionable101&sort=img_timestamp&asc=&desc=1
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?user=Fashionable101&sort=img_timestamp&asc=&desc=1
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?dir=prev&user=Fashionable101&sort=img_timestamp&asc=&desc=1
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?dir=prev&offset=20200318202715%7CRichard_Stahl.png&user=Fashionable101&sort=img_timestamp&asc=&desc=1
# Crawling: https://criminalminds.fandom.com/wiki/Special:ListFiles?offset=20200505011013%7CRileyJenkins.jpg&user=Fashionable101&sort=img_timestamp&asc=&desc=1
# Crawling: https://criminalminds.fandom.com/wiki/File:Richard_Stahl.png
# Crawling: https://criminalminds.fandom.com/wiki/Category:Criminal_Minds_Characters
# Crawling: https://criminalminds.fandom.com/wiki/Category:Content
# Crawling: https://criminalminds.fandom.com/wiki/Category:Content?action=history
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?page=Category%3AContent
# Crawling: https://criminalminds.fandom.com/wiki/Category_talk:Content?action=edit&redlink=1
# Failed to retrieve https://criminalminds.fandom.com/wiki/Category_talk:Content?action=edit&redlink=1: 404 Client Error: Not Found for url: https://criminalminds.fandom.com/wiki/Category_talk:Content
# Crawling: https://criminalminds.fandom.com/wiki/Category:Content?diff=166772&oldid=2903
# Crawling: https://criminalminds.fandom.com/wiki/Category:Content?oldid=2903
# Crawling: https://criminalminds.fandom.com/wiki/Category:Content?diff=cur&oldid=2903
# Crawling: https://criminalminds.fandom.com/wiki/Category:Content?action=edit&oldid=2903
# Crawling: https://criminalminds.fandom.com/wiki/Special:Preferences
# Crawling: https://criminalminds.fandom.com/register?source=signin&redirect=https%3A%2F%2Fauth.fandom.com%2Fauth%2Fredirect%3Fredirect%3Dhttps%25253A%25252F%25252Fcriminalminds.fandom.com%25252Fwiki%25252FSpecial%25253APreferences%25253Fcb%25253D9028%252526%26redirected_from%3Dsignin%26source%3Dmw_redirect
# Crawling: https://criminalminds.fandom.com/signin?source=register&redirect=https%3A%2F%2Fauth.fandom.com%2Fauth%2Fredirect%3Fredirect%3Dhttps%25253A%25252F%25252Fcriminalminds.fandom.com%25252Fwiki%25252FSpecial%25253APreferences%25253Fcb%25253D9028%252526%26redirected_from%3Dregister%26source%3Dsignin
# Crawling: https://criminalminds.fandom.com/register?source=signin&redirect=https%3A%2F%2Fauth.fandom.com%2Fauth%2Fredirect%3Fredirect%3Dhttps%25253A%25252F%25252Fcriminalminds.fandom.com%25252Fwiki%25252FSpecial%25253APreferences%25253Fcb%25253D9028%252526%26redirected_from%3Dsignin%26source%3Dregister
# Crawling: https://criminalminds.fandom.com/reset-password?source=signin&redirect=https://auth.fandom.com/auth/redirect?redirect=https%253A%252F%252Fcriminalminds.fandom.com%252Fwiki%252FSpecial%253APreferences%253Fcb%253D9028%2526&redirected_from=signin&source=register&backButton=true
# Crawling: https://criminalminds.fandom.com/register?source=recovery&redirect=https%3A%2F%2Fauth.fandom.com%2Fauth%2Fredirect%3Fredirect%3Dhttps%253A%252F%252Fcriminalminds.fandom.com%252Fwiki%252FSpecial%253APreferences%253Fcb%253D9028%2526
# Crawling: https://criminalminds.fandom.com/signin?source=register&redirect=https%3A%2F%2Fauth.fandom.com%2Fauth%2Fredirect%3Fredirect%3Dhttps%253A%252F%252Fcriminalminds.fandom.com%252Fwiki%252FSpecial%253APreferences%253Fcb%253D9028%2526%26redirected_from%3Dregister%26source%3Drecovery
# Crawling: https://criminalminds.fandom.com/register?source=signin&redirect=https%3A%2F%2Fauth.fandom.com%2Fauth%2Fredirect%3Fredirect%3Dhttps%253A%252F%252Fcriminalminds.fandom.com%252Fwiki%252FSpecial%253APreferences%253Fcb%253D9028%2526%26redirected_from%3Dsignin%26source%3Dregister
# Crawling: https://criminalminds.fandom.com/signin?source=register&redirect=https%3A%2F%2Fauth.fandom.com%2Fauth%2Fredirect%3Fredirect%3Dhttps%253A%252F%252Fcriminalminds.fandom.com%252Fwiki%252FSpecial%253APreferences%253Fcb%253D9028%2526%26redirected_from%3Dregister%26source%3Dsignin
# Crawling: https://criminalminds.fandom.com/reset-password?source=signin&redirect=https://auth.fandom.com/auth/redirect?redirect=https%3A%2F%2Fcriminalminds.fandom.com%2Fwiki%2FSpecial%3APreferences%3Fcb%3D9028%26&redirected_from=signin&source=register&backButton=true
# Crawling: https://criminalminds.fandom.com/register?source=recovery&redirect=https%3A%2F%2Fauth.fandom.com%2Fauth%2Fredirect%3Fredirect%3Dhttps%3A%2F%2Fcriminalminds.fandom.com%2Fwiki%2FSpecial%3APreferences%3Fcb%3D9028%26
# Crawling: https://criminalminds.fandom.com/signin?source=register&redirect=https%3A%2F%2Fauth.fandom.com%2Fauth%2Fredirect%3Fredirect%3Dhttps%253A%252F%252Fcriminalminds.fandom.com%252Fwiki%252FSpecial%253APreferences%253Fcb%253D9028%26redirected_from%3Dregister%26source%3Drecovery
# Crawling: https://criminalminds.fandom.com/register?source=signin&redirect=https%3A%2F%2Fauth.fandom.com%2Fauth%2Fredirect%3Fredirect%3Dhttps%253A%252F%252Fcriminalminds.fandom.com%252Fwiki%252FSpecial%253APreferences%253Fcb%253D9028%26redirected_from%3Dsignin%26source%3Dregister
# Crawling: https://criminalminds.fandom.com/signin?source=register&redirect=https%3A%2F%2Fauth.fandom.com%2Fauth%2Fredirect%3Fredirect%3Dhttps%253A%252F%252Fcriminalminds.fandom.com%252Fwiki%252FSpecial%253APreferences%253Fcb%253D9028%26redirected_from%3Dregister%26source%3Dsignin
# Crawling: https://criminalminds.fandom.com/reset-password?source=signin&redirect=https://auth.fandom.com/auth/redirect?redirect=https%3A%2F%2Fcriminalminds.fandom.com%2Fwiki%2FSpecial%3APreferences%3Fcb%3D9028&redirected_from=signin&source=register&backButton=true
# Crawling: https://criminalminds.fandom.com/register?source=recovery&redirect=https%3A%2F%2Fauth.fandom.com%2Fauth%2Fredirect%3Fredirect%3Dhttps%3A%2F%2Fcriminalminds.fandom.com%2Fwiki%2FSpecial%3APreferences%3Fcb%3D9028
# Crawling: https://criminalminds.fandom.com/reset-password?source=signin&redirect=https://auth.fandom.com/auth/redirect?redirect=https%253A%252F%252Fcriminalminds.fandom.com%252Fwiki%252FSpecial%253APreferences%253Fcb%253D9028%2526&redirected_from=signin&source=mw_redirect&backButton=true
# Crawling: https://criminalminds.fandom.com/wiki/Template:Category
# Crawling: https://criminalminds.fandom.com/wiki/Category:Category_templates
# Crawling: https://criminalminds.fandom.com/wiki/Category:Templates
# Crawling: https://criminalminds.fandom.com/wiki/Category:Organization
# Crawling: https://criminalminds.fandom.com/wiki/Category:Organization?action=history
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?page=Category%3AOrganization
# Crawling: https://criminalminds.fandom.com/wiki/Category_talk:Organization?action=edit&redlink=1
# Failed to retrieve https://criminalminds.fandom.com/wiki/Category_talk:Organization?action=edit&redlink=1: 404 Client Error: Not Found for url: https://criminalminds.fandom.com/wiki/Category_talk:Organization
# Crawling: https://criminalminds.fandom.com/wiki/Category:Organization?oldid=3110
# Crawling: https://criminalminds.fandom.com/wiki/Joe_Clark
# Crawling: https://criminalminds.fandom.com/wiki/Category:Real_World_Criminals
# Crawling: https://criminalminds.fandom.com/wiki/Category:Real_People
# Crawling: https://criminalminds.fandom.com/wiki/Category:Real_World_Articles
# Crawling: https://criminalminds.fandom.com/wiki/Category:Real_World_Articles?action=history
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?page=Category%3AReal+World+Articles
# Crawling: https://criminalminds.fandom.com/wiki/Category_talk:Real_World_Articles?action=edit&redlink=1
# Failed to retrieve https://criminalminds.fandom.com/wiki/Category_talk:Real_World_Articles?action=edit&redlink=1: 404 Client Error: Not Found for url: https://criminalminds.fandom.com/wiki/Category_talk:Real_World_Articles
# Crawling: https://criminalminds.fandom.com/wiki/Category:Real_World_Articles?oldid=9252
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G#articleComments
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history
# Crawling: https://criminalminds.fandom.com/wiki/Special:Log?page=Criminal+Minds%3A+Actors%2FGuests+A-G
# Crawling: https://criminalminds.fandom.com/wiki/Talk:Criminal_Minds:_Actors/Guests_A-G?action=edit&redlink=1
# Failed to retrieve https://criminalminds.fandom.com/wiki/Talk:Criminal_Minds:_Actors/Guests_A-G?action=edit&redlink=1: 404 Client Error: Not Found for url: https://criminalminds.fandom.com/wiki/Talk:Criminal_Minds:_Actors/Guests_A-G
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20150818045108%7C86452
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20150907053329%7C87793
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20150920235314%7C88942
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20151014032742%7C90259
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20151113040507%7C92367
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20151219213459%7C94780
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20160621024114%7C106780
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20170109041228%7C113176
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20170303032440%7C117416
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20170525032501%7C122701
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20170731004809%7C129881
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20180228014150%7C146859
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20190730021212%7C176155
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20200329150848%7C191817
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20200816000804%7C201174
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20200816214224%7C201205
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20200330002817%7C191900
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20191216223543%7C185219
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20180304161806%7C146962
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20170803062844%7C130056
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20170525083331%7C122715
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20170305052855%7C117557
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20170109082052%7C113198
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20160627235034%7C106853
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20151227061801%7C95330
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20151113041307%7C92375
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20151014040854%7C90265
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20150922223559%7C89001
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20150907110820%7C87799
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20150818045252%7C86455
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&offset=20150818045252%7C86455&limit=20
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&limit=20
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&limit=20
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20150730171654%7C85081&limit=20
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20150809232526%7C85969&limit=20
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20150822032118%7C86731&limit=20
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20150828232253%7C87100&limit=20
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20150907053329%7C87793&limit=20
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20150915015436%7C88548&limit=20
# Crawling: https://criminalminds.fandom.com/wiki/Criminal_Minds:_Actors/Guests_A-G?action=history&dir=prev&offset=20150919195453%7C88816&limit=20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6788868df2c5> in <cell line: 56>()
#      54
#      55 # Begin crawling from the start URL
# ---> 56 crawl_wiki(start_url, visited_urls)
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# ...
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      47     for link in internal_links:
#      48         if link not in visited:
# ---> 49             crawl_wiki(link, visited)  # Recursive call
#      50
#      51 # Start URL
#
# <ipython-input-2-6788868df2c5> in crawl_wiki(url, visited)
#      43
#      44     # Get internal links on the page
# ---> 45     internal_links = get_internal_links(url, domain_name, visited)
#      46
#      47     for link in internal_links:
#
# <ipython-input-2-6788868df2c5> in get_internal_links(url, domain_name, visited)
#      10     try:
#      11         # Request the URL content
# ---> 12         response = requests.get(url)
#      13         response.raise_for_status()
#      14     except requests.exceptions.RequestException as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787
#     788             # Make the request on the HTTPConnection object
# --> 789             response = self._make_request(
#     790                 conn,
#     791                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534         # Receive the response from the server
#     535         try:
# --> 536             response = conn.getresponse()
#     537         except (BaseSSLError, OSError) as e:
#     538             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     505
#     506         # Get the response from http.client.HTTPConnection
# --> 507         httplib_response = super().getresponse()
#     508
#     509         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
